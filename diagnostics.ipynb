# %% [markdown]
# # Gathering Essential Diagnostic information
#
# ## Please run this next cell to gather some important data
#
# Please run the next cell; it should take a minute or so to run (mostly the network test).
# Rhen email me the output of the last cell to ed@edwarddonner.com.
# Alternatively: this will create a file called report.txt - just attach the file to your email.

# %%
# Run my diagnostics report to collect key information for debugging
# Please email me the results. Either copy & paste the output, or attach the file report.txt

# !pip install -q requests speedtest-cli psutil setuptools
from diagnostics import Diagnostics
Diagnostics().run()
# Out:
# Starting diagnostics at 2025-03-20 19:24:25
#
# ===== System Information =====
# Operating System: Darwin
# MacOS Version: 15.3.2
# Architecture: ('64bit', '')
# Machine: arm64
# Processor: arm
# Total RAM: 16.00 GB
# Available RAM: 5.95 GB
# Free Disk Space: 889.54 GB
#
# ===== File System Information =====
# Current Directory: /Users/woodzsan/Desktop/Machine Learning and Data Analysis/LLM_Engineering
# Write permission: OK
#
# Files in Current Directory:
#  - .env
#  - .git
#  - .gitignore
#  - .ipynb_checkpoints
#  - LICENSE
#  - README.md
#  - SETUP-PC.md
#  - SETUP-PC.pdf
#  - SETUP-linux.md
#  - SETUP-linux.pdf
#  - SETUP-mac.md
#  - SETUP-mac.pdf
#  - __pycache__
#  - business.jpg
#  - diagnostics.ipynb
#  - diagnostics.py
#  - environment.yml
#  - extras
#  - important.jpg
#  - report.txt
#  - requirements.txt
#  - resources.jpg
#  - thankyou.jpg
#  - voyage.jpg
#  - week1
#  - week2
#  - week3
#  - week4
#  - week5
#  - week6
#  - week7
#  - week8
#
# ===== Git Repository Information =====
# Git Repository Root: /Users/woodzsan/Desktop/Machine Learning and Data Analysis/LLM_Engineering
# Current Commit: 8ffd3a523feda2f0054f786d39f9e6eec78d4cf9
# Remote Origin: git@github.com:ROARMarketingConcepts/LLM_Engineering.git
#
# ===== Environment File Check =====
# .env file exists at: /Users/woodzsan/Desktop/Machine Learning and Data Analysis/LLM_Engineering/.env
# OPENAI_API_KEY found in .env file
#
# ===== Anaconda Environment Check =====
# Anaconda environment is active:
# Environment Path: /Users/woodzsan/anaconda3/envs/llms
# Environment Name: llms
# Conda Version: conda 24.11.3
#
# Python Environment:
# Python Version: 3.11.11 | packaged by conda-forge | (main, Mar  3 2025, 20:44:07) [Clang 18.1.8 ]
# Python Executable: /Users/woodzsan/anaconda3/envs/llms/bin/python
#
# Required Package Versions:
# openai: 1.67.0
# python-dotenv: 1.0.1
# requests: 2.32.3
# gradio: 5.22.0
# transformers: 4.49.0
#
# ===== Virtualenv Check =====
# No active virtualenv detected
#
# ===== Network Connectivity Check =====
# SSL Version: OpenSSL 3.4.1 11 Feb 2025
# ✓ Connected to https://www.google.com
#   Response time: 0.52s
#
# Performing bandwidth test using speedtest-cli...
# Download speed: 372.40 Mbps
# Upload speed: 73.54 Mbps
#
# ===== Environment Variables Check =====
#
# PYTHONPATH is not set.
#
# Python sys.path:
#  - /Users/woodzsan/anaconda3/envs/llms/lib/python311.zip
#  - /Users/woodzsan/anaconda3/envs/llms/lib/python3.11
#  - /Users/woodzsan/anaconda3/envs/llms/lib/python3.11/lib-dynload
#  -
#  - /Users/woodzsan/anaconda3/envs/llms/lib/python3.11/site-packages
#  - /Users/woodzsan/anaconda3/envs/llms/lib/python3.11/site-packages/setuptools/_vendor
# OPENAI_API_KEY is set after calling load_dotenv()
#
# ===== Additional Diagnostics =====
# Temp directory is writable: /var/folders/bs/zn7hxrnj0fx87gcf7r0jdfww0000gn/T
#
# ✅ All diagnostics passed successfully!
#
#
# Completed diagnostics at 2025-03-20 19:24:50
#
#
# Please send these diagnostics to me at ed@edwarddonner.com
# Either copy & paste the above output into an email, or attach the file report.txt that has been created in this directory.
